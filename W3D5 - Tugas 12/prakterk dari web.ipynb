# %%
import json, re, string
import pandas as pd
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory as SF
import nltk

# %%
df_news = pd.read_csv("berita.csv")

df_news
# Out:
#                                                  judul
# 0    Hakim PN Surabaya "Ngamuk" Saat KPK Umumkan Te...
# 1    Hakim Itong, Panitera dan Pengacara yang Terja...
# 2    Sejumlah Titik di Tegal Alur Masih Banjir, Pen...
# 3    Dari 1.000 KK, Hanya 15 Keluarga Korban Banjir...
# 4    Pertanyakan Progres Laporannya, Korban Penipua...
# ..                                                 ...
# 130  SMAN 6 Jakarta Kembali Gelar PTM Setelah Dihen...
# 131  Fraksi PDI-P Panggil Arteria Soal Ucapan Copot...
# 132  Jadi Calon Pangkostrad, I Nyoman Cantiasa Eks ...
# 133  2,1 Juta Anak Divaksinasi melalui Program Vaks...
# 134  Minta Maaf Setelah Diprotes Masyarakat Sunda, ...
#
# [135 rows x 1 columns]

# %%
def case_folding(data):
    data = data.lower()
    data = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",data).split())
    data = re.sub(r"\d+", "", data)
    data = data.translate(str.maketrans("","",string.punctuation))
    data = re.sub(r"\n","",data)
    data = re.sub(r"\t","",data)
    return data

# %%
def stopword_cleaner(data):
    sw_indonesia = stopwords.words("indonesian")
    data  = [word for word in data if word not in sw_indonesia]
    data = ' '.join(data)
    return data

# %%
for index in range (len(df_news["judul"])):
  df_news["judul"].iloc[index] = case_folding(df_news["judul"].iloc[index])
  df_news["judul"].iloc[index] = word_tokenize(df_news["judul"].iloc[index])
  df_news["judul"].iloc[index] = stopword_cleaner(df_news["judul"].iloc[index])

# %%
 
data_berita = [berita.split() for berita in df_news["judul"]]
data_berita
# Out:
# [['hakim',
#   'pn',
#   'surabaya',
#   'ngamuk',
#   'kpk',
#   'umumkan',
#   'tersangka',
#   'omong',
#   'kosong'],
#  ['hakim',
#   'itong',
#   'panitera',
#   'pengacara',
#   'terjaring',
#   'ott',
#   'pn',
#   'surabaya',
#   'tersangka'],
#  ['titik', 'tegal', 'alur', 'banjir', 'penyedotan', 'air', 'malam'],
#  ['kk', 'keluarga', 'korban', 'banjir', 'kecamatan', 'benda', 'mengungsi'],
#  ['progres',
#   'laporannya',
#   'korban',
#   'penipuan',
#   'apartemen',
#   'jaksel',
#   'datangi',
#   'polda',
#   'metro',
#   'jaya'],
#  ['ri',
#   'kecam',
#   'aksi',
#   'israel',
#   'gusur',
#   'permukiman',
#   'warga',
#   'palestina',
#   'sheikh',
#   'jarah'],
#  ['kecamatan', 'benda', 'dirikan', 'dapur', 'warga', 'terdampak', 'banjir'],
#  ['omicron',
#   'jakarta',
#   'wagub',
#   'dki',
#   'imbau',
#   'masyarakat',
#   'rumah',
#   'mendesak'],
#  ['satgas', 'covid', 'varian', 'indonesia', 'terkendali'],
#  ['habiskan',
#   'stok',
#   'pedagang',
#   'pasar',
#   'slipi',
#   'jual',
#   'minyak',
#   'goreng',
#   'rp',
#   'liter'],
#  ['kpk',
#   'sayangkan',
#   'rahmat',
#   'effendi',
#   'lakukan',
#   'pertemuan',
#   'daring',
#   'ketentuan'],
#  ['pasien', 'covid', 'varian', 'omicron', 'wisma', 'atlet', 'kematian'],
#  ['kemenlu',
#   'ri',
#   'butuh',
#   'informasi',
#   'lengkap',
#   'kirim',
#   'bantuan',
#   'tonga'],
#  ['warga',
#   'tanjung',
#   'duren',
#   'terkonfirmasi',
#   'positif',
#   'covid',
#   'varian',
#   'omicron'],
#  ['mengelak', 'pelaku', 'mengaku', 'cabuli', 'bocah', 'hasil', 'visum'],
#  ['kemenkes', 'covid', 'varian', 'omicron', 'tembus'],
#  ['warga',
#   'rangkapan',
#   'jaya',
#   'depok',
#   'temukan',
#   'jenazah',
#   'lansia',
#   'kebun',
#   'belimbing'],
#  ['hakim',
#   'pn',
#   'surabaya',
#   'ditangkap',
#   'itong',
#   'isnaeni',
#   'hidayat',
#   'gedung',
#   'kpk'],
#  ['satgas', 'covid', 'kali', 'lipat', 'pekan'],
#  ['anggota',
#   'satlantas',
#   'jaktim',
#   'dilarikan',
#   'rs',
#   'polri',
#   'akibat',
#   'ditabrak',
#   'pemotor',
#   'simpang',
#   'pgc'],
#  ['komplotan',
#   'pencuri',
#   'beraksi',
#   'komplek',
#   'deplu',
#   'gasak',
#   'spion',
#   'mobil',
#   'milik',
#   'warga'],
#  ['buron', 'tersangka', 'pengeroyokan', 'anggota', 'tni', 'ad', 'ditangkap'],
#  ['kemenlu', 'indonesia', 'kedatangan', 'vaksin', 'jerman', 'china'],
#  ['kementerian',
#   'kp',
#   'fokus',
#   'genjot',
#   'peluang',
#   'investasi',
#   'sektor',
#   'perikanan'],
#  ['kabur', 'kakak', 'bupati', 'langkat', 'gedung', 'merah', 'putih'],
#  ['kemenlu', 'malaysia', 'tindak', 'majikan', 'pekerjakan', 'pmi', 'ilegal'],
#  ['puluhan',
#   'kilogram',
#   'gulungan',
#   'kulit',
#   'kabel',
#   'ditemukan',
#   'saluran',
#   'air',
#   'jalan',
#   'bungur',
#   'raya'],
#  ['jokowi', 'peran', 'who', 'mencakup', 'strategis', 'dunia'],
#  ['suami',
#   'bunuh',
#   'istri',
#   'duren',
#   'sawit',
#   'korban',
#   'ditemukan',
#   'adiknya',
#   'tidur',
#   'dekatnya'],
#  ['aman',
#   'tukar',
#   'guling',
#   'lahan',
#   'konsesi',
#   'ikn',
#   'ancam',
#   'masyarakat',
#   'adat',
#   'wilayah'],
#  ['kepala', 'keluarga', 'kecamatan', 'benda', 'korban', 'banjir'],
#  ['rumah',
#   'direnovasi',
#   'dalih',
#   'arteria',
#   'dahlan',
#   'parkir',
#   'mobil',
#   'dpr'],
#  ['kemenlu',
#   'dorong',
#   'uni',
#   'emirat',
#   'arab',
#   'bantu',
#   'lepaskan',
#   'abk',
#   'wni',
#   'ditahan',
#   'milisi',
#   'houthi'],
#  ['dagangan',
#   'senilai',
#   'rp',
#   'juta',
#   'terendam',
#   'banjir',
#   'tegal',
#   'alur',
#   'pedagang',
#   'seperempatnya',
#   'selamat'],
#  ['pemerintah',
#   'alokasikan',
#   'anggaran',
#   'penurunan',
#   'stunting',
#   'rp',
#   'triliun'],
#  ['barang',
#   'bukti',
#   'ratusan',
#   'juta',
#   'rupiah',
#   'disita',
#   'kpk',
#   'ott',
#   'surabaya'],
#  ['pemkot', 'bekasi', 'pastikan', 'stok', 'vaksin', 'booster', 'januari'],
#  ['masyarakat', 'adat', 'tergusur', 'proyek', 'kota'],
#  ['bruder',
#   'angelo',
#   'divonis',
#   'penjara',
#   'kuasa',
#   'hukum',
#   'korban',
#   'adil'],
#  ['update', 'januari', 'cakupan', 'vaksinasi', 'covid', 'dosis', 'persen'],
#  ['kuli',
#   'bangunan',
#   'cabuli',
#   'bocah',
#   'pamulang',
#   'iming',
#   'imingi',
#   'korban',
#   'cokelat'],
#  ['arteria',
#   'dahlan',
#   'terancam',
#   'dipidana',
#   'terbukti',
#   'palsukan',
#   'pelat',
#   'mobil',
#   'polisi'],
#  ['kpk', 'amankan', 'orang', 'ott', 'surabaya'],
#  ['update', 'januari', 'aktif', 'covid', 'indonesia'],
#  ['update',
#   'januari',
#   'sebaran',
#   'harian',
#   'covid',
#   'indonesia',
#   'jakarta',
#   'tertinggi'],
#  ['update', 'januari', 'suspek', 'terkait', 'covid'],
#  ['update',
#   'januari',
#   'spesimen',
#   'diperiksa',
#   'sehari',
#   'positivity',
#   'rate',
#   'pcr',
#   'persen'],
#  ['korsleting',
#   'tiang',
#   'listrik',
#   'api',
#   'menyambar',
#   'gerobak',
#   'tanah',
#   'abang'],
#  ['update', 'januari', 'bertambah', 'total', 'sembuh', 'covid', 'capai'],
#  ['cerita',
#   'sepasang',
#   'lansia',
#   'bertahan',
#   'banjir',
#   'selamatkan',
#   'gerobak',
#   'jualan',
#   'aksesori',
#   'berharga'],
#  ['update', 'januari', 'pasien', 'covid', 'meninggal', 'bertambah', 'total'],
#  ['update', 'bertambah', 'covid', 'indonesia', 'capai'],
#  ['menko', 'pmk', 'dorong', 'penguatan', 'kursus', 'calon', 'pengantin'],
#  ['guru',
#   'smp',
#   'cendrawasih',
#   'i',
#   'cilandak',
#   'dijambret',
#   'uang',
#   'rp',
#   'juta',
#   'bayar',
#   'kontrakan',
#   'ponsel',
#   'raib'],
#  ['pemkot',
#   'tangerang',
#   'drainase',
#   'tol',
#   'jorr',
#   'ii',
#   'sebabkan',
#   'banjir',
#   'warga'],
#  ['oleng',
#   'pengemudi',
#   'toyota',
#   'rush',
#   'tabrak',
#   'mobil',
#   'motor',
#   'kebayoran',
#   'pemotor',
#   'terluka'],
#  ['hakim',
#   'pn',
#   'surabaya',
#   'terjaring',
#   'ott',
#   'ky',
#   'tunggu',
#   'pemeriksaan',
#   'kpk'],
#  ['tabrak',
#   'pohon',
#   'masuk',
#   'parit',
#   'tangerang',
#   'pengemudi',
#   'pajero',
#   'tewas'],
#  ['saluran',
#   'air',
#   'ditutup',
#   'warga',
#   'petugas',
#   'sda',
#   'saluran',
#   'jalan',
#   'bidara',
#   'raya',
#   'penjaringan'],
#  ['sekolah', 'tatap', 'muka', 'persen', 'cek', 'data', 'vaksinasi', 'pelajar'],
#  ['kompromi', 'damai', 'pelaku', 'kekerasan', 'seksual'],
#  ['hasil',
#   'tracing',
#   'tunjukkan',
#   'siswa',
#   'sman',
#   'jakarta',
#   'positif',
#   'covid',
#   'bukti',
#   'klaster',
#   'sekolah'],
#  ['nur',
#   'afifah',
#   'balqis',
#   'tersangka',
#   'korupsi',
#   'usia',
#   'pegang',
#   'uang',
#   'suap',
#   'rp',
#   'miliar',
#   'bupati',
#   'ppu'],
#  ['ipw',
#   'polri',
#   'usut',
#   'pelat',
#   'mobil',
#   'polisi',
#   'dpr',
#   'diduga',
#   'milik',
#   'arteria',
#   'dahlan'],
#  ['arogan', 'ditilang', 'pengguna', 'mobil', 'pelat', 'rf'],
#  ['kecelakaan',
#   'kapal',
#   'pengangkut',
#   'wni',
#   'kemenlu',
#   'malaysia',
#   'jalur',
#   'resmi'],
#  ['transformasi',
#   'energi',
#   'butuh',
#   'dana',
#   'jokowi',
#   'indonesia',
#   'kontribusi',
#   'negara',
#   'maju',
#   'pembiayaan'],
#  ['kebanjiran', 'warga', 'jurumudi', 'bantuan', 'pemkot', 'tangerang'],
#  ['wapres', 'ptm', 'persen', 'disesuaikan', 'kondisi', 'pandemi'],
#  ['kawasan',
#   'meikarta',
#   'direncanakan',
#   'lokasi',
#   'street',
#   'race',
#   'kabupaten',
#   'bekasi'],
#  ['guru', 'smp', 'cendrawasih', 'cilandak', 'dijambret', 'gerbang', 'sekolah'],
#  ['mahasiswi',
#   'universitas',
#   'indonesia',
#   'tewas',
#   'tertabrak',
#   'krl',
#   'pondok',
#   'cina'],
#  ['kpk',
#   'lakukan',
#   'penggeledahan',
#   'paksa',
#   'kantor',
#   'bupati',
#   'buru',
#   'selatan'],
#  ['arteria', 'pelat', 'nomor', 'mobilnya', 'polisi', 'tatakan'],
#  ['tawa',
#   'bocah',
#   'bermain',
#   'banjir',
#   'tegal',
#   'alur',
#   'senang',
#   'renang',
#   'gratis',
#   'tangkap',
#   'ikan'],
#  ['ott', 'surabaya', 'kpk', 'amankan', 'uang'],
#  ['lurah',
#   'gelora',
#   'tanah',
#   'abang',
#   'terpapar',
#   'covid',
#   'kantor',
#   'kelurahan',
#   'ditutup'],
#  ['sidang',
#   'mk',
#   'ahli',
#   'presiden',
#   'dorong',
#   'penelitian',
#   'efektivitas',
#   'ganja',
#   'keperluan',
#   'medis'],
#  ['sosok',
#   'mayjen',
#   'teguh',
#   'pudjo',
#   'kandidat',
#   'pangkostrad',
#   'lulusan',
#   'terbaik',
#   'akmil',
#   'viral'],
#  ['harga',
#   'minyak',
#   'goreng',
#   'pasar',
#   'kramatjati',
#   'rp',
#   'liter',
#   'pedagang',
#   'mengeluh',
#   'sepi',
#   'pembeli'],
#  ['satgas',
#   'blbi',
#   'sita',
#   'bidang',
#   'tanah',
#   'milik',
#   'texmaco',
#   'kota',
#   'rinciannya'],
#  ['rt',
#   'jakarta',
#   'terendam',
#   'banjir',
#   'kemarin',
#   'penjelasan',
#   'dinas',
#   'sda'],
#  ['banjir', 'kecamatan', 'benda', 'sentimeter'],
#  ['polri',
#   'berkoordinasi',
#   'bi',
#   'terkait',
#   'dugaan',
#   'kebocoran',
#   'data',
#   'viral'],
#  ['suami',
#   'bunuh',
#   'istri',
#   'duren',
#   'sawit',
#   'hubungan',
#   'badan',
#   'akibat',
#   'korban',
#   'nikah'],
#  ['tegal',
#   'alur',
#   'dilanda',
#   'hujan',
#   'warga',
#   'khawatir',
#   'ketinggian',
#   'banjir',
#   'bertambah'],
#  ['cabuli', 'bocah', 'pamulang', 'kuli', 'bangunan', 'ditangkap', 'polisi'],
#  ['semangati',
#   'pengusaha',
#   'jasa',
#   'dekorasi',
#   'wagub',
#   'jatim',
#   'kendur',
#   'pesimis'],
#  ['kemenlu',
#   'kecelakaan',
#   'kapal',
#   'pengangkut',
#   'wni',
#   'perairan',
#   'johor',
#   'berturutan'],
#  ['politikus', 'pks', 'peredaran', 'narkoba', 'kepala', 'bnn'],
#  ['muncul', 'polemik', 'arteria', 'doakan'],
#  ['area',
#   'tpu',
#   'semper',
#   'kebanjiran',
#   'diuruk',
#   'tanah',
#   'buangan',
#   'mrt',
#   'jakarta'],
#  ['ucapan',
#   'copot',
#   'kajati',
#   'arteria',
#   'niat',
#   'diskreditkan',
#   'suku',
#   'sunda'],
#  ['sidang',
#   'mk',
#   'ahli',
#   'presiden',
#   'setuju',
#   'ganja',
#   'obat',
#   'konservatif'],
#  ['hasil',
#   'tracing',
#   'sman',
#   'jakarta',
#   'siswa',
#   'dinyatakan',
#   'positif',
#   'covid'],
#  ['perumahan',
#   'vida',
#   'bekasi',
#   'dipertimbangkan',
#   'lokasi',
#   'street',
#   'race'],
#  ['prabowo',
#   'pembelian',
#   'pesawat',
#   'f',
#   'ex',
#   'tahap',
#   'negosiasi',
#   'dassault',
#   'rafale',
#   'tinggal',
#   'aktifkan',
#   'kontrak'],
#  ['vonis', 'diketok', 'bruder', 'angelo', 'akui', 'perbuatan', 'cabulnya'],
#  ['arteria',
#   'ucapan',
#   'ganti',
#   'kajati',
#   'pendapat',
#   'pribadi',
#   'wakili',
#   'fraksi',
#   'pdi',
#   'p'],
#  ['dishub',
#   'dki',
#   'bus',
#   'transjakarta',
#   'rute',
#   'senen',
#   'jis',
#   'diuji',
#   'coba'],
#  ['pdi',
#   'p',
#   'sanksi',
#   'peringatan',
#   'arteria',
#   'buntut',
#   'pernyataan',
#   'singgung',
#   'bahasa',
#   'sunda'],
#  ['polisi',
#   'gagalkan',
#   'pengiriman',
#   'pmi',
#   'ilegal',
#   'malaysia',
#   'tersangka',
#   'ditangkap'],
#  ['ahli', 'presiden', 'ganja', 'dipakai', 'medis', 'obat', 'aman', 'efektif'],
#  ['kemenlu', 'wni', 'tonga', 'selamat'],
#  ['kuasa', 'hukum', 'bruder', 'angelo', 'vonis', 'penjara'],
#  ['arteria', 'dahlan', 'maaf', 'anggap', 'orang', 'sunda', 'keluarga'],
#  ['ri',
#   'beli',
#   'jet',
#   'tempur',
#   'dassault',
#   'rafale',
#   'prabowo',
#   'tinggal',
#   'aktifkan',
#   'kontrak'],
#  ['ott', 'kpk', 'pukat', 'ugm', 'biar', 'jera', 'bongkar', 'tuntas'],
#  ['pedagang',
#   'roti',
#   'korban',
#   'begal',
#   'bekasi',
#   'saksi',
#   'pelaku',
#   'remaja'],
#  ['kepala',
#   'daerah',
#   'jatim',
#   'wagub',
#   'emil',
#   'mari',
#   'pastikan',
#   'pungutan',
#   'liar',
#   'sma',
#   'smk'],
#  ['banjir', 'surut', 'jam', 'janji', 'anies', 'penjelasan', 'wagub', 'dki'],
#  ['cegah',
#   'vaksin',
#   'covid',
#   'kedaluwarsa',
#   'kemenkes',
#   'dinkes',
#   'percepat',
#   'laju',
#   'vaksinasi',
#   'primer',
#   'booster'],
#  ['prabowo',
#   'rencana',
#   'pembelian',
#   'pesawat',
#   'tempur',
#   'f',
#   'ex',
#   'tahap',
#   'negosiasi'],
#  ['pasien',
#   'covid',
#   'rsdc',
#   'wisma',
#   'atlet',
#   'tambahan',
#   'tenaga',
#   'kesehatan'],
#  ['gugat',
#   'anies',
#   'ptun',
#   'apindo',
#   'besaran',
#   'kenaikan',
#   'ump',
#   'regulasinya'],
#  ['dishub', 'dki', 'siapkan', 'moda', 'transportasi', 'masyarakat', 'jis'],
#  ['batasi',
#   'mobilitas',
#   'dishub',
#   'dki',
#   'pertahankan',
#   'aturan',
#   'ganjil',
#   'genap',
#   'ruas',
#   'jalan'],
#  ['pelaku',
#   'cabul',
#   'bruder',
#   'angelo',
#   'divonis',
#   'penjara',
#   'hakim',
#   'merusak',
#   'mental',
#   'anak'],
#  ['dugaan', 'korupsi', 'satelit', 'kemenhan', 'prabowo', 'diproses'],
#  ['jokowi', 'halangi', 'maju', 'nyapres'],
#  ['pemindahan',
#   'kota',
#   'koalisi',
#   'jakarta',
#   'diselesaikan',
#   'menciptakan',
#   'kaltim'],
#  ['bnn', 'bantah', 'daftar', 'target', 'operasi', 'kalangan', 'selebritas'],
#  ['tanggapi',
#   'pelat',
#   'nomor',
#   'polisi',
#   'milik',
#   'arteria',
#   'dahlan',
#   'ketua',
#   'fraksi',
#   'pdi',
#   'p'],
#  ['ribut',
#   'kritik',
#   'kajati',
#   'berbahasa',
#   'sunda',
#   'arogansi',
#   'arteria',
#   'dahlan',
#   'berujung',
#   'permintaan',
#   'maaf'],
#  ['terjaring',
#   'ott',
#   'kpk',
#   'hakim',
#   'itong',
#   'diskors',
#   'bebaskan',
#   'terdakwa',
#   'korupsi'],
#  ['update',
#   'januari',
#   'pasien',
#   'covid',
#   'wisma',
#   'atlet',
#   'bertambah',
#   'orang'],
#  ['masyarakat', 'panic', 'buying', 'distribusi', 'minyak', 'goreng', 'merata'],
#  ['fico',
#   'fachriza',
#   'ajukan',
#   'rehabilitasi',
#   'narkoba',
#   'polda',
#   'metro',
#   'jaya',
#   'tunggu',
#   'asesmen',
#   'bnn'],
#  ['ketua', 'fraksi', 'pdi', 'p', 'arteria', 'dahlan', 'dibina'],
#  ['keberatan',
#   'divonis',
#   'penjara',
#   'pelaku',
#   'cabul',
#   'bruder',
#   'angelo',
#   'ajukan',
#   'banding'],
#  ['sman',
#   'jakarta',
#   'gelar',
#   'ptm',
#   'dihentikan',
#   'sepekan',
#   'akibat',
#   'covid'],
#  ['fraksi',
#   'pdi',
#   'p',
#   'panggil',
#   'arteria',
#   'ucapan',
#   'copot',
#   'kajati',
#   'berbahasa',
#   'sunda',
#   'mobil',
#   'pelat',
#   'nomor',
#   'polisi'],
#  ['calon',
#   'pangkostrad',
#   'i',
#   'nyoman',
#   'cantiasa',
#   'eks',
#   'danjen',
#   'kopassus',
#   'janji',
#   'hancurkan',
#   'teroris',
#   'papua'],
#  ['juta', 'anak', 'divaksinasi', 'program', 'vaksinasi', 'merdeka'],
#  ['maaf',
#   'diprotes',
#   'masyarakat',
#   'sunda',
#   'arteria',
#   'dahlan',
#   'disanksi',
#   'pdi',
#   'p']]
