# %%
import re
from unittest import result
import requests
from bs4 import BeautifulSoup
import pandas as pd
import string
from nltk.corpus import stopwords
import string

# %%
df = pd.read_csv("kompas_20211201.csv")
df
# Out:
#     Unnamed: 0        date                                              title
# 0            0  2021-12-01  Chelsea Vs Liverpool, Gelar Juara Sangat Berar...
# 1            1  2021-12-01  Warga Mamasa Antre Minyak Goreng hingga Mengul...
# 2            2  2021-12-01  Menurun, Kini Tersisa 21 Pasien Covid-19 Jalan...
# 3            3  2021-12-01  Libur Panjang Isra Miraj, 347.711 Kendaraan Ti...
# 4            4  2021-12-01  Mulai 1 Maret, Pemerintah Pangkas Karantina Tu...
# 5            5  2021-12-01  Mengenal Trofi Alan Hardaker, Penghargaan Pema...
# 6            6  2021-12-01  Mengenal SWIFT, Sistem Keuangan Global yang Di...
# 7            7  2021-12-01  Makan Saat Malam Hari Tidak Sehat? Ini Jam Mak...
# 8            8  2021-12-01  Gejala Omicron Siluman dan Orang yang Rentan T...
# 9            9  2021-12-01          Cara Menghilangkan Bau Jamur dari Pakaian
# 10          10  2021-12-01  Seblak Bandung Makanan Populer hingga ke Luar ...
# 11          11  2021-12-01  Arahan Presiden Jokowi soal Jumlah Penonton Mo...
# 12          12  2021-12-01  Penyebab Manusia Bermimpi Saat Tidur Menurut S...
# 13          13  2021-12-01  Kesetiaan De Zerbi kepada Pemain Shakhtar Done...
# 14          14  2021-12-01  PDI-P: Tangani Kenaikan Harga Kebutuhan Pokok ...

# %%
df['title']= df['title'].str.lower() #lower
df['title']= df['title'].str.strip() #whitespace
df['title']= df['title'].str.replace('\d+', '') #remove number
df['title']= df['title'].str.replace(r'[^\w\s]+', '')
#del df['Unnamed: 0']
df
# Out:
# C:\Users\LENOVO~1\AppData\Local\Temp/ipykernel_1644/2612693303.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['title']= df['title'].str.replace('\d+', '') #remove number
# C:\Users\LENOVO~1\AppData\Local\Temp/ipykernel_1644/2612693303.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['title']= df['title'].str.replace(r'[^\w\s]+', '')
#           date                                              title
# 0   2021-12-01  chelsea vs liverpool gelar juara tim muda the ...
# 1   2021-12-01  warga mamasa antre minyak goreng mengular jala...
# 2   2021-12-01  menurun tersisa pasien covid jalani isolasi gr...
# 3   2021-12-01  libur isra miraj kendaraan tinggalkan jabodeta...
# 4   2021-12-01     maret pemerintah pangkas karantina turis asing
# 5   2021-12-01  mengenal trofi alan hardaker penghargaan pemai...
# 6   2021-12-01  mengenal swift sistem keuangan global dipelint...
# 7   2021-12-01              makan malam sehat jam makan kesehatan
# 8   2021-12-01     gejala omicron siluman orang rentan terinfeksi
# 9   2021-12-01                    menghilangkan bau jamur pakaian
# 10  2021-12-01     seblak bandung makanan populer jawa rahasianya
# 11  2021-12-01   arahan presiden jokowi penonton motogp mandalika
# 12  2021-12-01              penyebab manusia bermimpi tidur sains
# 13  2021-12-01  kesetiaan de zerbi pemain shakhtar donetsk tin...
# 14  2021-12-01  pdip tangani kenaikan harga kebutuhan pokok me...

# %%
stop = stopwords.words('indonesian')
test = pd.DataFrame(df)
test['title'] = test['title'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))
print(test)
# Out:
#           date                                              title
# 0   2021-12-01  chelsea vs liverpool gelar juara tim muda the ...
# 1   2021-12-01  warga mamasa antre minyak goreng mengular jala...
# 2   2021-12-01  menurun tersisa pasien covid jalani isolasi gr...
# 3   2021-12-01  libur isra miraj kendaraan tinggalkan jabodeta...
# 4   2021-12-01     maret pemerintah pangkas karantina turis asing
# 5   2021-12-01  mengenal trofi alan hardaker penghargaan pemai...
# 6   2021-12-01  mengenal swift sistem keuangan global dipelint...
# 7   2021-12-01              makan malam sehat jam makan kesehatan
# 8   2021-12-01     gejala omicron siluman orang rentan terinfeksi
# 9   2021-12-01                    menghilangkan bau jamur pakaian
# 10  2021-12-01     seblak bandung makanan populer jawa rahasianya
# 11  2021-12-01   arahan presiden jokowi penonton motogp mandalika
# 12  2021-12-01              penyebab manusia bermimpi tidur sains
# 13  2021-12-01  kesetiaan de zerbi pemain shakhtar donetsk tin...
# 14  2021-12-01  pdip tangani kenaikan harga kebutuhan pokok me...

# %%
df = pd.DataFrame(df)

df.to_csv('kompas_20211201_clean.csv', encoding="utf-8")
